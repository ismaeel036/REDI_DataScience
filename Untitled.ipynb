# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
grtn = pd.read_excel('./2019/Actual_generation_2019.xlsx')

grtn = grtn.dropna()
grtn.head()
# Out:
#   Data category: Actual generation   Unnamed: 1    Unnamed: 2  \
# 5                             Date  Time of day  Biomass[MWh]
# 6                      Jan 1, 2019     12:00 AM        1231.5
# 7                      Jan 1, 2019     12:15 AM       1234.25
# 8                      Jan 1, 2019     12:30 AM        1231.5
# 9                      Jan 1, 2019     12:45 AM        1233.5
#
#         Unnamed: 3          Unnamed: 4         Unnamed: 5          Unnamed: 6  \
# 5  Hydropower[MWh]  Wind offshore[MWh]  Wind onshore[MWh]  Photovoltaics[MWh]
# 6              401              794.75               4751                   0
# 7           394.75                 794            4937.25                   0
# 8           381.25              792.25             5118.5                   0
# 9              381               755.5            5188.75                   0
#
#              Unnamed: 7    Unnamed: 8              Unnamed: 9  \
# ...

# %%
grtn_new.head()
# Out:
# 5                   Biomass[MWh] Hydropower[MWh] Wind offshore[MWh]  \
# DateTime
# 2019-01-01 00:00:00       1231.5             401             794.75
# 2019-01-01 00:15:00      1234.25          394.75                794
# 2019-01-01 00:30:00       1231.5          381.25             792.25
# 2019-01-01 00:45:00       1233.5             381              755.5
# 2019-01-01 01:00:00         1229          388.25              715.5
#
# 5                   Wind onshore[MWh] Photovoltaics[MWh] Other renewable[MWh]  \
# DateTime
# 2019-01-01 00:00:00              4751                  0                 27.5
# 2019-01-01 00:15:00           4937.25                  0                 27.5
# 2019-01-01 00:30:00            5118.5                  0                 27.5
# 2019-01-01 00:45:00           5188.75                  0                 27.5
# 2019-01-01 01:00:00            5297.5                  0                 27.5
#
# ...

# %%
grtn.head()
#Update Column Headings with right information on row 2 and delete this row in the dataframe
#grtn.columns = grtn.iloc[0]
#grtn = grtn.drop(grtn_new.index[0])


'''
grtn_new['DateTime'] = grtn_new['Date'] + ' ' + grtn_new['Time of day']

grtn_new['DateTime'] = pd.to_datetime(grtn_new['DateTime'])

grtn_new = grtn_new.set_index(grtn_new['DateTime'])

grtn_new = grtn_new.drop(['Date','Time of day'], axis=1)

grtn_new.head()
'''
# Out:
# "\ngrtn_new['DateTime'] = grtn_new['Date'] + ' ' + grtn_new['Time of day']\n\ngrtn_new['DateTime'] = pd.to_datetime(grtn_new['DateTime'])\n\ngrtn_new = grtn_new.set_index(grtn_new['DateTime'])\n\ngrtn_new = grtn_new.drop(['Date','Time of day'], axis=1)\n\ngrtn_new.head()\n"
